# %%
import soundfile # to read audio file
import numpy as np
import librosa # to extract speech features
import glob
import os
import pickle # to save model after training
import pandas as pd
import sklearn
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.model_selection import train_test_split # for splitting training and testing
from sklearn.neural_network import MLPClassifier # multi-layer perceptron model
from sklearn.metrics import accuracy_score, f1_score # to measure how good we are
from sklearn.tree import DecisionTreeClassifier


import tensorflow as tf
from functools import partial
from tensorflow import keras
from tensorflow.keras.layers import Conv1D, Conv2D,MaxPooling1D,MaxPooling2D, Dense, Flatten, Reshape, Dropout

# %% [markdown]
# ## Prepare Training Data
# this will take some time

# %%
def extract_feature(file_name, **kwargs):
    """
    Extract feature from audio file `file_name`
        Features supported:
            - MFCC (mfcc)
            - Chroma (chroma)
            - MEL Spectrogram Frequency (mel)
            - Contrast (contrast)
        e.g:
        `features = extract_feature(path, mel=True, mfcc=True)`
    """
    mfcc = kwargs.get("mfcc")
    chroma = kwargs.get("chroma")
    mel = kwargs.get("mel")
    contrast = kwargs.get("contrast")

    if chroma or contrast:
        X, sample_rate = librosa.load(file_name)
        stft = np.abs(librosa.stft(X))
    result = np.array([])

    if mfcc:
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
        result = np.hstack((result, mfccs))
    if chroma:
        chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
        result = np.hstack((result, chroma))
    if mel:
        mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
        result = np.hstack((result, mel))

    return result

# all emotions on RAVDESS dataset
# int2emotion = {
#     "01": "neutral",
#     "02": "calm",
#     "03": "happy",
#     "04": "sad",
#     "05": "angry",
#     "06": "fearful",
#     "07": "disgust",
#     "08": "surprised"
# }

# we allow only these emotions ( feel free to tune this on your need )
# AVAILABLE_EMOTIONS = {
#     "angry",
#     "sad",
#     "neutral",
#     "happy"
# }

# 1 positive
# 0 negative
EMOTIONS_AVAILABLE = [1, 1, 1, 0, 0, 0, 0, 1]

def load_data(test_size=0.2):
    X, y = [], []
    for file in glob.glob("data/Actor_*/*.wav"):
        # get the base name of the audio file
        basename = os.path.basename(file)
        # get the emotion label, we allow only AVAILABLE_EMOTIONS we set
        emotion = EMOTIONS_AVAILABLE[int(basename.split("-")[2])-1]
        # extract speech features
        features = extract_feature(file, mfcc=True, chroma=True, mel=True)
        # add to data
        X.append(features)
        y.append(emotion)
    # split the data to training and testing and return it
    return train_test_split(np.array(X), y, test_size=test_size, random_state=7)

# load RAVDESS dataset, 75% training 25% testing
X_train, X_test, y_train, y_test = load_data(test_size=0.25)

# %%
#save data to csv files
pd.DataFrame(X_train).to_csv("./prepared-data/X_train.csv")
pd.DataFrame(X_test).to_csv("./prepared-data/X_test.csv")
pd.DataFrame(y_train).to_csv("./prepared-data/y_train.csv")
pd.DataFrame(y_test).to_csv("./prepared-data/y_test.csv")

# %% [markdown]
# If data is avaliable in prepared-data folder, can start the program from here

# %%
#load data from csv files
X_train = pd.read_csv(os.path.join("./prepared-data/", "X_train.csv")).to_numpy()
X_test = pd.read_csv(os.path.join("./prepared-data/", "X_test.csv")).to_numpy()
y_train = pd.read_csv(os.path.join("./prepared-data/", "y_train.csv")).to_numpy()
y_test = pd.read_csv(os.path.join("./prepared-data/", "y_test.csv")).to_numpy()

X_train = X_train[:,1:]
X_test = X_test[:,1:]
y_train = y_train[:,1]
y_test = y_test[:,1]

# %% [markdown]
# ### Random Forest

# %%
def en_model_rfc(xtrain,xtest,ytrain,ytest):
    print("\n Random Forest")
    reg = RandomForestClassifier(n_estimators=120, max_leaf_nodes=15, 
                                 n_jobs=-1, random_state=42)
    reg.fit(xtrain, ytrain)
    print("Accuracy: ", reg.score(xtest, ytest))
    y_pred = reg.predict(xtest)
    return reg
    
model_rf = en_model_rfc(X_train, X_test, y_train, y_test)
# Out:
#  Random Forest
# Accuracy:  0.6916666666666667

# %%
pickle.dump(model_rf, open("trained-model/rf_classifier.model", "wb"))

# %% [markdown]
# ### AdaBoost

# %%
def en_model_ada(xtrain,xtest,ytrain,ytest):
    print("\n AdaBoost")
    reg = AdaBoostClassifier(
            DecisionTreeClassifier(max_depth=3), n_estimators=100,
            algorithm="SAMME.R", learning_rate=0.5, random_state=42)
    
    reg.fit(xtrain, ytrain)
    print("Accuracy: ", reg.score(xtest, ytest))
    y_pred = reg.predict(xtest)
    return reg
    
model_ada = en_model_ada(X_train, X_test, y_train, y_test)
# Out:
#  AdaBoost
# Accuracy:  0.7055555555555556

# %%
pickle.dump(model_ada, open("trained-model/ada_classifier.model", "wb"))

# %% [markdown]
# ### Multi-layer Perceptron

# %%
# best model, determined by a grid search
model_params = {
    'alpha': 0.01,
    'batch_size': 256,
    'epsilon': 1e-08, 
    'hidden_layer_sizes': (300,), 
    'learning_rate': 'adaptive', 
    'max_iter': 500, 
}

model = MLPClassifier(**model_params)
model.fit(X_train, y_train)

# predict 25% of data to measure how good we are
y_pred = model.predict(X_test)

# calculate the accuracy
accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)

print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 61.39%

# %% [markdown]
# ## CNN

# %%
np.random.seed(42)
tf.random.set_seed(42)

# checkpoint_path = "/content/gdrive/MyDrive/Trained_Model/training_1/cp.ckpt"
checkpoint_path = "trained-model/training-1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

model = keras.models.Sequential([
    Conv1D(filters = 120, kernel_size = 180, input_shape=(180, 1)),
    Reshape((120,1)),
    Dropout(0.2),
    Conv1D(filters = 1, kernel_size = 10, input_shape=(120, 1)),
    MaxPooling1D(pool_size=(2)),
    Dropout(0.2),
    Conv1D(filters = 1, kernel_size = 2, input_shape=(55, 1)),
    MaxPooling1D(pool_size=(2)),
    Flatten(),
    Dense(units=27, activation='relu'),
    Dropout(0.1),
    Dense(units=1, activation='sigmoid'),
])

# %%
model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_36 (Conv1D)           (None, 1, 120)            21720
# _________________________________________________________________
# reshape_16 (Reshape)         (None, 120, 1)            0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 120, 1)            0
# _________________________________________________________________
# conv1d_37 (Conv1D)           (None, 111, 1)            11
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 55, 1)             0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 55, 1)             0
# _________________________________________________________________
# conv1d_38 (Conv1D)           (None, 54, 1)             3
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 27, 1)             0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 27)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 27)                756
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 27)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 28
# =================================================================
# Total params: 22,518
# Trainable params: 22,518
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train_cnn = X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test_cnn = X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %%
model.compile(
    loss="binary_crossentropy", 
    optimizer="adam",
    metrics=["accuracy"])

history = model.fit(X_train_cnn,
                    y_train, 
                    epochs=80, 
                    batch_size=32, 
                    validation_data = (X_test_cnn, y_test),
                    callbacks = [cp_callback])
# Out:
# Epoch 1/80
# 28/34 [=======================>......] - ETA: 0s - loss: 0.8825 - accuracy: 0.5379
# Epoch 00001: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 6ms/step - loss: 0.8642 - accuracy: 0.5426 - val_loss: 0.6719 - val_accuracy: 0.5556
# Epoch 2/80
# 29/34 [========================>.....] - ETA: 0s - loss: 0.7222 - accuracy: 0.5647
# Epoch 00002: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 3ms/step - loss: 0.7125 - accuracy: 0.5657 - val_loss: 0.6607 - val_accuracy: 0.6000
# Epoch 3/80
# 28/34 [=======================>......] - ETA: 0s - loss: 0.6739 - accuracy: 0.5692
# Epoch 00003: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 3ms/step - loss: 0.6769 - accuracy: 0.5648 - val_loss: 0.6687 - val_accuracy: 0.5500
# Epoch 4/80
# 27/34 [======================>.......] - ETA: 0s - loss: 0.6587 - accuracy: 0.5648
# Epoch 00004: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 3ms/step - loss: 0.6642 - accuracy: 0.5611 - val_loss: 0.6865 - val_accuracy: 0.5417
# Epoch 5/80
# 22/34 [==================>...........] - ETA: 0s - loss: 0.6716 - accuracy: 0.5412
# Epoch 00005: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 4ms/step - loss: 0.6739 - accuracy: 0.5444 - val_loss: 0.6651 - val_accuracy: 0.5639
# Epoch 6/80
# 23/34 [===================>..........] - ETA: 0s - loss: 0.6655 - accuracy: 0.5666
# Epoch 00006: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 4ms/step - loss: 0.6638 - accuracy: 0.5639 - val_loss: 0.6579 - val_accuracy: 0.5667
# Epoch 7/80
# 27/34 [======================>.......] - ETA: 0s - loss: 0.6503 - accuracy: 0.5775
# Epoch 00007: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 3ms/step - loss: 0.6534 - accuracy: 0.5750 - val_loss: 0.6580 - val_accuracy: 0.5667
# Epoch 8/80
# 27/34 [======================>.......] - ETA: 0s - loss: 0.6369 - accuracy: 0.5752
# Epoch 00008: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 3ms/step - loss: 0.6405 - accuracy: 0.5704 - val_loss: 0.6677 - val_accuracy: 0.5611
# Epoch 9/80
# 27/34 [======================>.......] - ETA: 0s - loss: 0.6471 - accuracy: 0.5903
# Epoch 00009: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 3ms/step - loss: 0.6498 - accuracy: 0.5917 - val_loss: 0.6625 - val_accuracy: 0.5833
# Epoch 10/80
# 26/34 [=====================>........] - ETA: 0s - loss: 0.6448 - accuracy: 0.5733
# Epoch 00010: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 3ms/step - loss: 0.6434 - accuracy: 0.5769 - val_loss: 0.6668 - val_accuracy: 0.5500
# Epoch 11/80
# 27/34 [======================>.......] - ETA: 0s - loss: 0.6372 - accuracy: 0.5752
# Epoch 00011: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 3ms/step - loss: 0.6384 - accuracy: 0.5769 - val_loss: 0.6668 - val_accuracy: 0.5528
# Epoch 12/80
# 27/34 [======================>.......] - ETA: 0s - loss: 0.6276 - accuracy: 0.5972
# Epoch 00012: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 3ms/step - loss: 0.6286 - accuracy: 0.6046 - val_loss: 0.6575 - val_accuracy: 0.5694
# Epoch 13/80
# 26/34 [=====================>........] - ETA: 0s - loss: 0.6272 - accuracy: 0.6214
# Epoch 00013: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 3ms/step - loss: 0.6313 - accuracy: 0.6056 - val_loss: 0.6592 - val_accuracy: 0.5694
# Epoch 14/80
# 28/34 [=======================>......] - ETA: 0s - loss: 0.6278 - accuracy: 0.5848
# Epoch 00014: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 3ms/step - loss: 0.6283 - accuracy: 0.5889 - val_loss: 0.6599 - val_accuracy: 0.5889
# Epoch 15/80
# 26/34 [=====================>........] - ETA: 0s - loss: 0.6283 - accuracy: 0.6106
# Epoch 00015: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 3ms/step - loss: 0.6254 - accuracy: 0.6157 - val_loss: 0.6612 - val_accuracy: 0.5639
# Epoch 16/80
# 29/34 [========================>.....] - ETA: 0s - loss: 0.6201 - accuracy: 0.6239
# Epoch 00016: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 3ms/step - loss: 0.6231 - accuracy: 0.6204 - val_loss: 0.6570 - val_accuracy: 0.5750
# Epoch 17/80
# 27/34 [======================>.......] - ETA: 0s - loss: 0.6225 - accuracy: 0.6007
# Epoch 00017: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 3ms/step - loss: 0.
80
# 23/34 [===================>..........] - ETA: 0s - loss: 0.5000 - accuracy: 0.7391
# Epoch 00069: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 4ms/step - loss: 0.5106 - accuracy: 0.7259 - val_loss: 0.6245 - val_accuracy: 0.6833
# Epoch 70/80
# 24/34 [====================>.........] - ETA: 0s - loss: 0.5144 - accuracy: 0.7201
# Epoch 00070: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 4ms/step - loss: 0.5073 - accuracy: 0.7167 - val_loss: 0.6761 - val_accuracy: 0.6694
# Epoch 71/80
# 20/34 [================>.............] - ETA: 0s - loss: 0.5083 - accuracy: 0.7047
# Epoch 00071: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 4ms/step - loss: 0.5141 - accuracy: 0.7204 - val_loss: 0.6764 - val_accuracy: 0.6528
# Epoch 72/80
# 23/34 [===================>..........] - ETA: 0s - loss: 0.5214 - accuracy: 0.6984
# Epoch 00072: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 4ms/step - loss: 0.5151 - accuracy: 0.7102 - val_loss: 0.6405 - val_accuracy: 0.6750
# Epoch 73/80
# 21/34 [=================>............] - ETA: 0s - loss: 0.5324 - accuracy: 0.7188
# Epoch 00073: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 4ms/step - loss: 0.5228 - accuracy: 0.7102 - val_loss: 0.6272 - val_accuracy: 0.6750
# Epoch 74/80
# 19/34 [===============>..............] - ETA: 0s - loss: 0.4734 - accuracy: 0.7467
# Epoch 00074: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 5ms/step - loss: 0.4919 - accuracy: 0.7324 - val_loss: 0.6507 - val_accuracy: 0.6500
# Epoch 75/80
# 21/34 [=================>............] - ETA: 0s - loss: 0.4889 - accuracy: 0.7574
# Epoch 00075: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 5ms/step - loss: 0.4869 - accuracy: 0.7463 - val_loss: 0.6202 - val_accuracy: 0.6750
# Epoch 76/80
# 18/34 [==============>...............] - ETA: 0s - loss: 0.5202 - accuracy: 0.7292
# Epoch 00076: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 5ms/step - loss: 0.5011 - accuracy: 0.7370 - val_loss: 0.6195 - val_accuracy: 0.6667
# Epoch 77/80
# 23/34 [===================>..........] - ETA: 0s - loss: 0.5087 - accuracy: 0.7310
# Epoch 00077: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 4ms/step - loss: 0.5098 - accuracy: 0.7287 - val_loss: 0.6201 - val_accuracy: 0.6556
# Epoch 78/80
# 23/34 [===================>..........] - ETA: 0s - loss: 0.4965 - accuracy: 0.7228
# Epoch 00078: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 4ms/step - loss: 0.5026 - accuracy: 0.7231 - val_loss: 0.6190 - val_accuracy: 0.6889
# Epoch 79/80
# 19/34 [===============>..............] - ETA: 0s - loss: 0.4991 - accuracy: 0.7319
# Epoch 00079: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 5ms/step - loss: 0.4961 - accuracy: 0.7417 - val_loss: 0.6315 - val_accuracy: 0.6806
# Epoch 80/80
# 21/34 [=================>............] - ETA: 0s - loss: 0.4863 - accuracy: 0.7530
# Epoch 00080: saving model to trained-model/training-1/cp.ckpt
# 34/34 [==============================] - 0s 4ms/step - loss: 0.4841 - accuracy: 0.7472 - val_loss: 0.6188 - val_accuracy: 0.6750

# %%
score, acc = model.evaluate(X_test_cnn, y_test)
print("Accuracy: ",acc)
y_pred = np.round(model(X_test_cnn))
print("F1: ", sklearn.metrics.f1_score(y_pred, y_test))
# Out:
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6188 - accuracy: 0.6750
# Accuracy:  0.675000011920929
# F1:  0.7167070217917676

# %%
model.save("trained-model/cnn_classifier")
# Out:
# WARNING:tensorflow:From /home/elim/anaconda3/envs/hex-cam/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: trained-model/cnn_classifier/assets
